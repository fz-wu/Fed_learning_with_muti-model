# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from pandas import DataFrame as df
import pandas as pd
iris = load_iris()
x_train,x_test,y_train,y_test = train_test_split(iris.data, iris.target,test_size=0.01)
X = df(x_train, columns=iris.feature_names)
# print(X)
Y = df(y_train, columns=['target'])
dataset = pd.concat([X, Y], axis=1)

print(dataset)
dataset.to_csv('iris.csv', index=False)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)

# print(x_train)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.7               2.5                5.0               2.0
# 1                  4.7               3.2                1.3               0.2
# 2                  5.7               2.9                4.2               1.3
# 3                  5.9               3.0                4.2               1.5
# 4                  6.7               3.1                4.7               1.5
# ..                 ...               ...                ...               ...
# 143                5.1               2.5                3.0               1.1
# 144                6.7               3.0                5.2               2.3
# 145                5.5               2.6                4.4               1.2
# 146                5.1               3.5                1.4               0.2
# 147                5.7               2.8                4.1               1.3
#
#      target
# 0         2
# 1         0
# 2         1
# 3         1
# 4         1
# ..      ...
# 143       1
# 144       2
# 145       1
# 146       0
# 147       1
#
# [148 rows x 5 columns]
